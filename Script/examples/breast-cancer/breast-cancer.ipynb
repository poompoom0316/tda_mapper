# %% [markdown]
# ## Plotly plot of the kmapper graph associated to the breast cancer dataset

# %%
import sys
try:
    import pandas as pd
except ImportError as e:
    print("pandas is required for this example. Please install with conda or pip  and then try again.")
    sys.exit()

import numpy as np
import sklearn
from sklearn import ensemble
import kmapper as km
from kmapper.plotlyviz import *

import warnings
warnings.filterwarnings("ignore")

# %%
import plotly.graph_objs as go
from ipywidgets import (HBox, VBox)

# %%
# Data - the Wisconsin Breast Cancer Dataset
# https://www.kaggle.com/uciml/breast-cancer-wisconsin-data
df = pd.read_csv("../data/breast-cancer.csv")
feature_names = [c for c in df.columns if c not in ["id", "diagnosis"]]
df["diagnosis"] = df["diagnosis"].apply(lambda x: 1 if x == "M" else 0)
X = np.array(df[feature_names].fillna(0))
y = np.array(df["diagnosis"])

# Create a custom 1-D lens with Isolation Forest
model = ensemble.IsolationForest(random_state=1729)
model.fit(X)
lens1 = model.decision_function(X).reshape((X.shape[0], 1))

# Create another 1-D lens with L2-norm
mapper = km.KeplerMapper(verbose=0)
lens2 = mapper.fit_transform(X, projection="l2norm")

# Combine both lenses to get a 2-D [Isolation Forest, L^2-Norm] lens
lens = np.c_[lens1, lens2]

# Define the simplicial complex
scomplex = mapper.map(lens,
                      X,
                      clusterer=sklearn.cluster.KMeans(n_clusters=2,
                                                       random_state=3471))

# %% [markdown]
# First we visualize the resulting graph via a   `color_function` that associates to lens data   their  x-coordinate distance to min, and  colormap these coordinates  to a given Plotly colorscale. Here we use the brewer colorscale with hex color codes.

# %%
scomplex
# Out:
# {'nodes': defaultdict(list,
#              {'cube5_cluster0': [78],
#               'cube5_cluster1': [12],
#               'cube12_cluster0': [352],
#               'cube12_cluster1': [180],
#               'cube13_cluster0': [68, 71],
#               'cube13_cluster1': [314],
#               'cube17_cluster0': [0, 181, 567],
#               'cube17_cluster1': [202],
#               'cube19_cluster0': [368],
#               'cube19_cluster1': [82],
#               'cube21_cluster0': [151, 192, 504, 505, 538, 568],
#               'cube21_cluster1': [288, 379],
#               'cube22_cluster0': [38, 112, 290],
#               'cube22_cluster1': [562],
#               'cube25_cluster0': [219],
#               'cube25_cluster1': [202],
#               'cube26_cluster0': [236, 339, 503],
#               'cube26_cluster1': [521],
#               'cube27_cluster0': [101, 116, 176, 318, 376, 391, 520, 539],
#               'cube27_cluster1': [146, 473, 561],
#               'cube28_cluster0': [138, 257, 351],
#               'cube28_cluster1': [14, 112, 146, 178, 473],
#               'cube29_cluster0': [138, 203, 257, 259, 351],
#               'cube29_cluster1': [119, 491],
#               'cube30_cluster0': [161, 210, 343, 366],
#               'cube30_cluster1': [25, 83, 389],
#               'cube31_cluster0': [393, 564],
#               'cube31_cluster1': [210, 252, 323, 563],
#               'cube32_cluster0': [18, 23],
#               'cube32_cluster1': [272, 369],
#               'cube33_cluster0': [232, 242, 275, 319, 382, 388, 450],
#               'cube33_cluster1': [60, 61, 63, 140, 175, 307, 345, 424, 557],
#               'cube34_cluster0': [14, 178, 247, 270, 308, 319, 360, 485, 528],
#               'cube34_cluster1': [15, 26, 31, 105, 196, 430, 509],
#               'cube35_cluster0': [197, 262, 277, 400, 441],
#               'cube35_cluster1': [22, 157, 509],
#               'cube36_cluster0': [72,
#                77,
#                168,
#                302,
#                321,
#                343,
#                366,
#                417,
#                533,
#                565],
#               'cube36_cluster1': [186, 277, 400, 451, 468],
#               'cube37_cluster0': [24, 162, 300],
#               'cube37_cluster1': [1,
#                33,
#                70,
#                95,
#                233,
#                237,
#                250,
#                256,
#                260,
#                302,
#                373,
#                449,
#                565],
#               'cube38_cluster0': [164],
#               'cube38_cluster1': [18],
#               'cube39_cluster0': [46,
#                59,
#                97,
#                113,
#                114,
#                173,
#                174,
#                185,
#                217,
#                245,
#                296,
#                358,
#                412,
#                416,
#                425,
#                443,
#                459,
#                507,
#                525,
#                550,
#                553,
#                555,
#                556],
#               'cube39_cluster1': [41,
#                139,
#                145,
#                231,
#                281,
#                305,
#                315,
#                327,
#                332,
#                354,
#                382,
#                456,
#                469,
#                471,
#                493,
#                537,
#                559],
#               'cube40_cluster0': [5,
#                8,
#                37,
#                58,
#                76,
#                191,
#                193,
#                229,
#                281,
#                284,
#                287,
#                309,
#                315,
#                327,
#                360,
#                407,
#                455,
#                465,
#                471,
#                493],
#               'cube40_cluster1': [13,
#                62,
#                92,
#                147,
#                196,
#                209,
#                214,
#                238,
#                298,
#                311,
#                385,
#                414,
#                462,
#                484,
#                501,
#                509],
#               'cube41_cluster0': [10,
#                17,
#                28,
#                32,
#                34,
#                35,
#                53,
#                75,
#                118,
#                156,
#                207,
#                230,
#                261,
#                262,
#                274,
#                335,
#                370,
#                441,
#                566],
#               'cube41_cluster1': [13,
#                62,
#                172,
#                199,
#                209,
#                263,
#                329,
#                353,
#                414,
#                479,
#                489,
#                509],
#               'cube42_cluster0': [27, 53, 186, 239, 244, 274, 335, 446],
#               'cube42_cluster1': [2,
#                4,
#                30,
#                45,
#                85,
#                87,
#                121,
#                127,
#                129,
#                134,
#                198,
#                280,
#                282,
#                372,
#                432,
#                433,
#                460,
#                487,
#                498,
#                517],
#               'cube43_cluster0': [1, 56, 70, 218, 254, 337],
#               'cube43_cluster1': [95, 365, 499, 535],
#               'cube44_cluster0': [21,
#                66,
#                104,
#                110,
#                139,
#                144,
#                166,
#                206,
#                226,
#                234,
#                248,
#                269,
#                273,
#                299,
#                303,
#                320,
#                341,
#                359,
#                390,
#                425,
#                428,
#                467,
#                474,
#                522,
#                524,
#                534,
#                546,
#                547,
#                548,
#                551],
#               'cube44_cluster1': [50,
#                80,
#                96,
#                102,
#                111,
#                120,
#                136,
#                159,
#                160,
#                170,
#                183,
#                188,
#                216,
#                241,
#                276,
#                281,
#                286,
#                289,
#                297,
#                310,
#                313,
#                316,
#                327,
#                333,
#                334,
#                349,
#                350,
#                355,
#                380,
#                398,
#                404,
#                419,
#                427,
#                440,
#                445,
#                452,
#                469,
#                510,
#                540,
#                549],
#               'cube45_cluster0': [58,
#                81,
#                102,
#                111,
#                124,
#                136,
#                150,
#                160,
#                170,
#                179,
#                208,
#                216,
#                241,
#                246,
#                267,
#                281,
#                284,
#                285,
#                286,
#                297,
#                306,
#                316,
#                327,
#                334,
#                336,
#                350,
#                355,
#                377,
#                397,
#                402,
#                404,
#                409,
#                429,
#                452,
#                457,
#                458,
#                466,
#                482,
#                494,
#                518,
#                543,
#                552,
#                554],
#               'cube45_cluster1': [7,
#                13,
#                39,
#                40,
#                43,
#                44,
#                47,
#                57,
#                64,
#                65,
#                73,
#                86,
#                89,
#                91,
#                100,
#                123,
#                126,
#                128,
#                133,
#                149,
#                165,
#                169,
#                171,
#                184,
#                194,
#                215,
#                225,
#                243,
#                278,
#                298,
#                326,
#                347,
#                357,
#                371,
#                375,
#                385,
#                387,
#                421,
#                435,
#                438,
#                439,
#                442,
#                453,
#                462,
#                472,
#                477,
#                481,
#                486,
#                495,
#                500,
#                511,
#                512,
#                514,
#                532,
#                536,
#                541,
#                542,
#                558,
#                560],
#               'cube46_cluster0': [13,
#                16,
#                54,
#                57,
#                94,
#                117,
#                133,
#                172,
#                177,
#                184,
#                205,
#                223,
#                283,
#                330,
#                363,
#                375,
#                406,
#                508,
#                514],
#               'cube46_cluster1': [10,
#                11,
#                29,
#                75,
#                131,
#                132,
#                141,
#                167,
#                182,
#                201,
#                253,
#                328,
#                392,
#                408,
#                444],
#               'cube47_cluster0': [244, 264, 317, 408, 444, 492, 516],
#               'cube47_cluster1': [6, 121, 134, 487, 498, 517],
#               'cube48_cluster0': [50,
#                52,
#                55,
#                67,
#                84,
#                98,
#                106,
#                107,
#                109,
#                115,
#                120,
#                130,
#                137,
#                142,
#                155,
#                158,
#                163,
#                170,
#                187,
#                189,
#                211,
#                249,
#                251,
#                293,
#                301,
#                304,
#                310,
#                344,
#                346,
#                348,
#                386,
#                394,
#                399,
#                410,
#                415,
#                420,
#                422,
#                427,
#                431,
#                463,
#                478,
#                480,
#                488,
#                502,
#                506,
#                515,
#                527,
#                529,
#                530,
#                531],
#               'cube48_cluster1': [103,
#                153,
#                206,
#                222,
#                266,
#                271,
#                338,
#                342,
#                381,
#                390,
#                405,
#                411,
#                426,
#                470,
#                534,
#                547],
#               'cube49_cluster0': [20,
#                48,
#                52,
#                69,
#                74,
#                79,
#                84,
#                88,
#                107,
#                115,
#                130,
#                135,
#                143,
#                155,
#                158,
#                163,
#                170,
#                189,
#                195,
#                200,
#                204,
#                211,
#                228,
#                268,
#                292,
#                294,
#                301,
#                312,
#                322,
#                324,
#                325,
#                331,
#                336,
#                346,
#                356,
#                361,
#                362,
#                367,
#                383,
#                384,
#                386,
#                394,
#                399,
#                401,
#                403,
#                418,
#                431,
#                436,
#                454,
#                457,
#                475,
#                480,
#                482,
#                488,
#                490,
#                496,
#                497,
#                502,
#                506,
#                519,
#                527,
#                529,
#                530,
#                531],
#               'cube49_cluster1': [19,
#                36,
#                40,
#                43,
#                49,
#                51,
#                73,
#                90,
#                93,
#                99,
#                123,
#                125,
#                148,
#                154,
#                220,
#                221,
#                224,
#                227,
#                235,
#                240,
#                255,
#                279,
#                291,
#                295,
#                340,
#                357,
#                364,
#                374,
#                378,
#                395,
#                396,
#                413,
#                423,
#                434,
#                437,
#                447,
#                448,
#                453,
#                464,
#                466,
#                476,
#                483,
#                513,
#                514,
#                523,
#                526,
#                532,
#                544,
#                545]}),
#  'links': defaultdict(list,
#              {'cube17_cluster1': ['cube25_cluster1'],
#               'cube22_cluster0': ['cube28_cluster1'],
#               'cube27_cluster1': ['cube28_cluster1'],
#               'cube28_cluster0': ['cube29_cluster0'],
#               'cube28_cluster1': ['cube34_cluster0'],
#               'cube30_cluster0': ['cube31_cluster1', 'cube36_cluster0'],
#               'cube32_cluster0': ['cube38_cluster1'],
#               'cube33_cluster0': ['cube34_cluster0', 'cube39_cluster1'],
#               'cube34_cluster0': ['cube40_cluster0'],
#               'cube34_cluster1': ['cube35_cluster1',
#                'cube40_cluster1',
#                'cube41_cluster1'],
#               'cube35_cluster0': ['cube36_cluster1', 'cube41_cluster0'],
#               'cube35_cluster1': ['cube40_cluster1', 'cube41_cluster1'],
#               'cube36_cluster0': ['cube37_cluster1'],
#               'cube36_cluster1': ['cube42_cluster0'],
#               'cube37_cluster1': ['cube43_cluster0', 'cube43_cluster1'],
#               'cube39_cluster0': ['cube44_cluster0'],
#               'cube39_cluster1': ['cube40_cluster0',
#                'cube44_cluster0',
#                'cube44_cluster1',
#                'cube45_cluster0'],
#               'cube40_cluster0': ['cube44_cluster1', 'cube45_cluster0'],
#               'cube40_cluster1': ['cube41_cluster1',
#                'cube45_cluster1',
#                'cube46_cluster0'],
#               'cube41_cluster0': ['cube42_cluster0', 'cube46_cluster1'],
#               'cube41_cluster1': ['cube45_cluster1', 'cube46_cluster0'],
#               'cube42_cluster0': ['cube47_cluster0'],
#               'cube42_cluster1': ['cube47_cluster1'],
#               'cube44_cluster0': ['cube48_cluster1'],
#               'cube44_cluster1': ['cube45_cluster0',
#                'cube48_cluster0',
#                'cube49_cluster0'],
#               'cube45_cluster0': ['cube48_cluster0',
#                'cube49_cluster0',
#                'cube49_cluster1'],
#               'cube45_cluster1': ['cube46_cluster0', 'cube49_cluster1'],
#               'cube46_cluster0': ['cube49_cluster1'],
#               'cube46_cluster1': ['cube47_cluster0'],
#               'cube48_cluster0': ['cube49_cluster0']}),
#  'simplices': [['cube5_cluster0'],
#   ['cube5_cluster1'],
#   ['cube12_cluster0'],
#   ['cube12_cluster1'],
#   ['cube13_cluster0'],
#   ['cube13_cluster1'],
#   ['cube17_cluster0'],
#   ['cube17_cluster1'],
#   ['cube19_cluster0'],
#   ['cube19_cluster1'],
#   ['cube21_cluster0'],
#   ['cube21_cluster1'],
#   ['cube22_cluster0'],
#   ['cube22_cluster1'],
#   ['cube25_cluster0'],
#   ['cube25_cluster1'],
#   ['cube26_cluster0'],
#   ['cube26_cluster1'],
#   ['cube27_cluster0'],
#   ['cube27_cluster1'],
#   ['cube28_cluster0'],
#   ['cube28_cluster1'],
#   ['cube29_cluster0'],
#   ['cube29_cluster1'],
#   ['cube30_cluster0'],
#   ['cube30_cluster1'],
#   ['cube31_cluster0'],
#   ['cube31_cluster1'],
#   ['cube32_cluster0'],
#   ['cube32_cluster1'],
#   ['cube33_cluster0'],
#   ['cube33_cluster1'],
#   ['cube34_cluster0'],
#   ['cube34_cluster1'],
#   ['cube35_cluster0'],
#   ['cube35_cluster1'],
#   ['cube36_cluster0'],
#   ['cube36_cluster1'],
#   ['cube37_cluster0'],
#   ['cube37_cluster1'],
#   ['cube38_cluster0'],
#   ['cube38_cluster1'],
#   ['cube39_cluster0'],
#   ['cube39_cluster1'],
#   ['cube40_cluster0'],
#   ['cube40_cluster1'],
#   ['cube41_cluster0'],
#   ['cube41_cluster1'],
#   ['cube42_cluster0'],
#   ['cube42_cluster1'],
#   ['cube43_cluster0'],
#   ['cube43_cluster1'],
#   ['cube44_cluster0'],
#   ['cube44_cluster1'],
#   ['cube45_cluster0'],
#   ['cube45_cluster1'],
#   ['cube46_cluster0'],
#   ['cube46_cluster1'],
#   ['cube47_cluster0'],
#   ['cube47_cluster1'],
#   ['cube48_cluster0'],
#   ['cube48_cluster1'],
#   ['cube49_cluster0'],
#   ['cube49_cluster1'],
#   ['cube17_cluster1', 'cube25_cluster1'],
#   ['cube22_cluster0', 'cube28_cluster1'],
#   ['cube27_cluster1', 'cube28_cluster1'],
#   ['cube28_cluster0', 'cube29_cluster0'],
#   ['cube28_cluster1', 'cube34_cluster0'],
#   ['cube30_cluster0', 'cube31_cluster1'],
#   ['cube30_cluster0', 'cube36_cluster0'],
#   ['cube32_cluster0', 'cube38_cluster1'],
#   ['cube33_cluster0', 'cube34_cluster0'],
#   ['cube33_cluster0', 'cube39_cluster1'],
#   ['cube34_cluster0', 'cube40_cluster0'],
#   ['cube34_cluster1', 'cube35_cluster1'],
#   ['cube34_cluster1', 'cube40_cluster1'],
#   ['cube34_cluster1', 'cube41_cluster1'],
#   ['cube35_cluster0', 'cube36_cluster1'],
#   ['cube35_cluster0', 'cube41_cluster0'],
#   ['cube35_cluster1', 'cube40_cluster1'],
#   ['cube35_cluster1', 'cube41_cluster1'],
#   ['cube36_cluster0', 'cube37_cluster1'],
#   ['cube36_cluster1', 'cube42_cluster0'],
#   ['cube37_cluster1', 'cube43_cluster0'],
#   ['cube37_cluster1', 'cube43_cluster1'],
#   ['cube39_cluster0', 'cube44_cluster0'],
#   ['cube39_cluster1', 'cube40_cluster0'],
#   ['cube39_cluster1', 'cube44_cluster0'],
#   ['cube39_cluster1', 'cube44_cluster1'],
#   ['cube39_cluster1', 'cube45_cluster0'],
#   ['cube40_cluster0', 'cube44_cluster1'],
#   ['cube40_cluster0', 'cube45_cluster0'],
#   ['cube40_cluster1', 'cube41_cluster1'],
#   ['cube40_cluster1', 'cube45_cluster1'],
#   ['cube40_cluster1', 'cube46_cluster0'],
#   ['cube41_cluster0', 'cube42_cluster0'],
#   ['cube41_cluster0', 'cube46_cluster1'],
#   ['cube41_cluster1', 'cube45_cluster1'],
#   ['cube41_cluster1', 'cube46_cluster0'],
#   ['cube42_cluster0', 'cube47_cluster0'],
#   ['cube42_cluster1', 'cube47_cluster1'],
#   ['cube44_cluster0', 'cube48_cluster1'],
#   ['cube44_cluster1', 'cube45_cluster0'],
#   ['cube44_cluster1', 'cube48_cluster0'],
#   ['cube44_cluster1', 'cube49_cluster0'],
#   ['cube45_cluster0', 'cube48_cluster0'],
#   ['cube45_cluster0', 'cube49_cluster0'],
#   ['cube45_cluster0', 'cube49_cluster1'],
#   ['cube45_cluster1', 'cube46_cluster0'],
#   ['cube45_cluster1', 'cube49_cluster1'],
#   ['cube46_cluster0', 'cube49_cluster1'],
#   ['cube46_cluster1', 'cube47_cluster0'],
#   ['cube48_cluster0', 'cube49_cluster0']],
#  'meta_data': {'projection': 'l2norm',
#   'n_cubes': 10,
#   'perc_overlap': 0.1,
#   'clusterer': 'KMeans(n_clusters=2, random_state=3471)',
#   'scaler': 'MinMaxScaler()'},
#  'meta_nodes': defaultdict(list, {})}

# %%
pl_brewer = [[0.0, '#006837'],
             [0.1, '#1a9850'],
             [0.2, '#66bd63'],
             [0.3, '#a6d96a'],
             [0.4, '#d9ef8b'],
             [0.5, '#ffffbf'],
             [0.6, '#fee08b'],
             [0.7, '#fdae61'],
             [0.8, '#f46d43'],
             [0.9, '#d73027'],
             [1.0, '#a50026']]

# %%
color_values = lens [:,0] - lens[:,0].min()
my_colorscale = pl_brewer
kmgraph,  mapper_summary, colorf_distribution = get_mapper_graph(scomplex, 
                                                                 color_values,  
                                                                 color_function_name='Distance to x-min', 
                                                                 colorscale=my_colorscale)

# assign to node['custom_tooltips']  the node label (0 for benign, 1 for malignant)
for node in kmgraph['nodes']:
    node['custom_tooltips'] = y[scomplex['nodes'][node['name']]]

# %%
X.shape
# Out:
# (569, 31)

# %% [markdown]
# Since the chosen colorscale leads  to a few light colors when it it used for histogram bars,
# we set a black background color to make the bars visible:

# %%
bgcolor = 'rgba(10,10,10, 0.9)'
y_gridcolor = 'rgb(150,150,150)'# on a black background the gridlines are set on  grey

# %%
plotly_graph_data = plotly_graph(kmgraph, graph_layout='fr', colorscale=my_colorscale, 
                                 factor_size=2.5, edge_linewidth=0.5)
layout = plot_layout(title='Topological network representing the<br>  breast cancer  dataset',  
                     width=620, height=570,
                     annotation_text=get_kmgraph_meta(mapper_summary),  
                     bgcolor=bgcolor)

fw_graph = go.FigureWidget(data=plotly_graph_data, layout=layout)
fw_hist = node_hist_fig(colorf_distribution, bgcolor=bgcolor,
                        y_gridcolor=y_gridcolor)
fw_summary = summary_fig(mapper_summary, height=300)
dashboard = hovering_widgets(kmgraph, 
                             fw_graph, 
                             ctooltips=True, # ctooltips = True, because we assigned a label to each 
                                             #cluster member
                             bgcolor=bgcolor,
                             y_gridcolor=y_gridcolor, 
                             member_textbox_width=600)

#Update the fw_graph colorbar, setting its title:
    
fw_graph.data[1].marker.colorbar.title = 'dist to<br>x-min'

# %%
VBox([fw_graph, HBox([fw_summary, fw_hist])])
# Out:
# VBox(children=(FigureWidget({
#     'data': [{'hoverinfo': 'none',
#               'line': {'color': 'rgb(180,180,…

# %%
dashboard
# Out:
# VBox(children=(HBox(children=(FigureWidget({
#     'data': [{'hoverinfo': 'none',
#               'line': {'color'…

# %% [markdown]
# In the following we illustrate how  we can duplicate FigureWidget(s) and update them. This is just a pretext to
# illustrate how the kmapper graph figure can be manipulated for a more in-depth study or for
# publication.

# %% [markdown]
# Here we duplicate the initial FigureWidget, `fw_graph`,  and recolor its  graph nodes according to the proportion of malignant members. The two FigureWidgets are then restyled and plotted alonside each other for comparison.

# %%
breastc_dict = {0: 'benign', 1: 'malignant'}
tooltips = list(fw_graph.data[1].text) # we perform this conversion because fw.data[1].text is a tuple and we want to update
                                     # the tooltips

new_color = []
for j, node in enumerate(kmgraph['nodes']):
    member_label_ids = y[scomplex['nodes'][node['name']]]
    member_labels = [breastc_dict[id] for id in member_label_ids]
    label_type, label_counts = np.unique(member_labels, return_counts=True) 
    
    n_members = label_counts.sum()
    if label_type.shape[0] == 1:
        if label_type[0] == 'benign':
            new_color.append(0)
        else:
            new_color.append(1)
    else:        
        new_color.append(1.0*label_counts[1]/n_members)#multiply by 1 for python 2.7.+
       
    for m in range(len(label_counts)):
        tooltips[j] += '<br>' + str(label_type[m]) + ': ' + str(label_counts[m]) # append  how many benign/malign 
                                                                                 # members exist in each node

fwn_graph = go.FigureWidget(fw_graph) # copy the initial FigureWidget

with fwn_graph.batch_update(): # make updates for the new figure                                                                
    fwn_graph.data[1].text = tooltips # add the new tooltips
    fwn_graph.data[1].marker.colorbar.x = -0.14 # place toolbar at the figure left side
    fwn_graph.layout.width = 550 # change the figure size in order to plot two "parallel" copies
    fwn_graph.layout.height = 550
    fwn_graph.layout.margin.r = 45 # decrease the right margin from 60px (default val) to 45 pixels
    
fw1 = go.FigureWidget(fwn_graph) # define a new figure from  the fwn_graph that will be colored by the new color function  
with fw1.batch_update():
    fw1.data[1].marker.color = new_color # update node colors
    fw1.data[0].line.color = 'rgb(125,125,125)' # update the graph edge color
    fw1.layout.plot_bgcolor = 'rgb(240,240,240)'
    fw1.layout.annotations = None # remove the mapper_summary from the second plot
    fw1.data[1].marker.showscale = False # remove the colorbar
    fw1.layout.title = "Nodes are colored according to the proportion<br> of malignant members"

# %% [markdown]
# Plot  the dashboard consisting in the two figures:

# %%
HBox([fwn_graph, fw1])
# Out:
# HBox(children=(FigureWidget({
#     'data': [{'hoverinfo': 'none',
#               'line': {'color': 'rgb(180,180,…

# %% [markdown]
# To save any of the FigureWidgets generated above uncomment the two lines  in the next cell, and replace `fw_graph` and the name of pdf file
# adequately:

# %%
#import plotly.io as pio
#pio.write_image(fw_graph, 'breast-graph1.pdf') # or png, swg
